# %% [markdown]
# # Introduction
#
# Notebook para avaliar dados de experimentos para validar proposta de NAS-v3 com **Reinforcement Learning** em comparação com algoritmos **Random** e **Regularized Evolution**.

# %% [markdown]
# # Import Libraries

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Load data

# %%
def get_best_arch(df, algo_name, dataset, max_train_hours):
    df = df[(df.algorithm == algo_name) & (df.dataset == dataset) & (df.max_train_hours == max_train_hours)]
    df = df.sort_values(by='val_acc', ascending=False)
    best = df.iloc[0]
    return best


algos_list = ['random','evolution','rl']
datasets_list = ['cifar10','cifar100','ImageNet16-120']
mth_list = [1,10,50,100,200]

results_list = []
for algo in algos_list:
    for ds in datasets_list:
        for mth in mth_list:
            config_name = f'sss/{algo}_{mth}h_{ds}'
            file_path = f'./results/final/{config_name}.csv'
            #file_path = f'./data/{config_name}.csv'
            df = pd.read_csv(file_path)
            print(f'Reading csv file: {file_path} | Shape: {df.shape}')
            best = df.iloc[0]
            results_list.append({'config_name': config_name, 'data':best})
# Out:
# Reading csv file: ./results/final/sss/random_1h_cifar10.csv | Shape: (68, 21)
# Reading csv file: ./results/final/sss/random_10h_cifar10.csv | Shape: (685, 21)
# Reading csv file: ./results/final/sss/random_50h_cifar10.csv | Shape: (3415, 21)
# Reading csv file: ./results/final/sss/random_100h_cifar10.csv | Shape: (6847, 21)
# Reading csv file: ./results/final/sss/random_200h_cifar10.csv | Shape: (13678, 21)
# Reading csv file: ./results/final/sss/random_1h_cifar100.csv | Shape: (37, 21)
# Reading csv file: ./results/final/sss/random_10h_cifar100.csv | Shape: (377, 21)
# Reading csv file: ./results/final/sss/random_50h_cifar100.csv | Shape: (1858, 21)
# Reading csv file: ./results/final/sss/random_100h_cifar100.csv | Shape: (3705, 21)
# Reading csv file: ./results/final/sss/random_200h_cifar100.csv | Shape: (7399, 21)
# Reading csv file: ./results/final/sss/random_1h_ImageNet16-120.csv | Shape: (25, 21)
# Reading csv file: ./results/final/sss/random_10h_ImageNet16-120.csv | Shape: (249, 21)
# Reading csv file: ./results/final/sss/random_50h_ImageNet16-120.csv | Shape: (1243, 21)
# Reading csv file: ./results/final/sss/random_100h_ImageNet16-120.csv | Shape: (2491, 21)
# Reading csv file: ./results/final/sss/random_200h_ImageNet16-120.csv | Shape: (4991, 21)
# Reading csv file: ./results/final/sss/evolution_1h_cifar10.csv | Shape: (67, 21)
# Reading csv file: ./results/final/sss/evolution_10h_cifar10.csv | Shape: (578, 21)
# Reading csv file: ./results/final/sss/evolution_50h_cifar10.csv | Shape: (2840, 21)
# Reading csv file: ./results/final/sss/evolution_100h_cifar10.csv | Shape: (5635, 21)
# Reading csv file: ./results/final/sss/evolution_200h_cifar10.csv | Shape: (11267, 21)
# Reading csv file: ./results/final/sss/evolution_1h_cifar100.csv | Shape: (39, 21)
# Reading csv file: ./results/final/sss/evolution_10h_cifar100.csv | Shape: (327, 21)
# Reading csv file: ./results/final/sss/evolution_50h_cifar100.csv | Shape: (1647, 21)
# Reading csv file: ./results/final/sss/evolution_100h_cifar100.csv | Shape: (3119, 21)
# Reading csv file: ./results/final/sss/evolution_200h_cifar100.csv | Shape: (6170, 21)
# Reading csv file: ./results/final/sss/evolution_1h_ImageNet16-120.csv | Shape: (25, 21)
# Reading csv file: ./results/final/sss/evolution_10h_ImageNet16-120.csv | Shape: (242, 21)
# Reading csv file: ./results/final/sss/evolution_50h_ImageNet16-120.csv | Shape: (1183, 21)
# Reading csv file: ./results/final/sss/evolution_100h_ImageNet16-120.csv | Shape: (2372, 21)
# Reading csv file: ./results/final/sss/evolution_200h_ImageNet16-120.csv | Shape: (4742, 21)
# Reading csv file: ./results/final/sss/rl_1h_cifar10.csv | Shape: (65, 22)
# Reading csv file: ./results/final/sss/rl_10h_cifar10.csv | Shape: (802, 22)
# Reading csv file: ./results/final/sss/rl_50h_cifar10.csv | Shape: (3121, 22)
# Reading csv file: ./results/final/sss/rl_100h_cifar10.csv | Shape: (7598, 22)
# Reading csv file: ./results/final/sss/rl_200h_cifar10.csv | Shape: (14032, 22)
# Reading csv file: ./results/final/sss/rl_1h_cifar100.csv | Shape: (36, 22)
# Reading csv file: ./results/final/sss/rl_10h_cifar100.csv | Shape: (403, 22)
# Reading csv file: ./results/final/sss/rl_50h_cifar100.csv | Shape: (1628, 22)
# Reading csv file: ./results/final/sss/rl_100h_cifar100.csv | Shape: (3442, 22)
# Reading csv file: ./results/final/sss/rl_200h_cifar100.csv | Shape: (7471, 22)
# Reading csv file: ./results/final/sss/rl_1h_ImageNet16-120.csv | Shape: (26, 22)
# Reading csv file: ./results/final/sss/rl_10h_ImageNet16-120.csv | Shape: (239, 22)
# Reading csv file: ./results/final/sss/rl_50h_ImageNet16-120.csv | Shape: (1234, 22)
# Reading csv file: ./results/final/sss/rl_100h_ImageNet16-120.csv | Shape: (2596, 22)
# Reading csv file: ./results/final/sss/rl_200h_ImageNet16-120.csv | Shape: (4819, 22)

# %% [markdown]
# # Plot Data

# %% [markdown]
# ## Utility Functions

# %%
metric_2_scalerange_map = {
    'val_acc'            : {'xlim':[0,100]       , 'xticks':range(0,100,10), 'unit_measure': '%'},
    'test_acc'           : {'xlim':[0,100]       , 'xticks':range(0,100,10), 'unit_measure': '%'},
    'train_accuracy'     : {'xlim':[0,100]       , 'xticks':range(0,100,10), 'unit_measure': '%'},
    'latency'            : {'xlim':[0,1e-1]      , 'xticks':np.arange(0,1e-1,1e-2), 'unit_measure': 'secs'},
    'total_time'         : {'xlim':[0,int(1e6)]  , 'xticks':range(0,int(1e6),int(2e5)), 'unit_measure': 'secs'},
    'time_cost'          : {'xlim':[0,200]       , 'xticks':range(0,200,20), 'unit_measure': 'secs'},
    'time_spent_in_hours': {'xlim':[0,200]       , 'xticks':range(0,200,20), 'unit_measure': 'hours'}
}


def __get_data(dataset, metric_name):
    results_filtered = [x for x in results_list if dataset == x['config_name'].split('_')[2]]

    configs = [x['config_name'].replace(f'_{dataset}','') for x in results_filtered]
    metric_values = [x['data'][metric_name] for x in results_filtered]
    
    return configs,metric_values


def __draw_subplot(ax, dataset, metric_name):
    configs, metric_values = __get_data(dataset, metric_name)
    colors_list = ['blue' for _ in range(5)] + ['orange' for _ in range(5)] + ['green' for _ in range(5)]
    ax.set_title(f'Best architecture found - {dataset.upper()}')
    ax.barh(configs, metric_values, color = colors_list)
    ax.set_xlabel(f'{metric_name.upper()} ({metric_2_scalerange_map[metric_name]["unit_measure"]})')
    ax.set_ylabel('Configuration')
    ax.grid()
    xlims = metric_2_scalerange_map[metric_name]['xlim']
    xticks = metric_2_scalerange_map[metric_name]['xticks']
    ax.set_xlim(xlims[0],xlims[1])
    ax.set_xticks(xticks)
    ylocs, ylabs = plt.yticks()
    if metric_name not in ['total_time','time_cost']:
        for i, v in enumerate(metric_values):
            ax.text(v + 0.01, ylocs[i] - 0.25, str(round(v,4)))
    return ax


def draw_bar_plots(metric_name):
    fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15,6), sharey=True)
    __draw_subplot(axes[0], 'cifar10',        metric_name)
    __draw_subplot(axes[1], 'cifar100',       metric_name)
    __draw_subplot(axes[2], 'ImageNet16-120', metric_name)
    plt.show()

# %% [markdown]
# ## Validation Accuracy

# %%
draw_bar_plots('val_acc')

# %% [markdown]
# ### Final

# %%
draw_bar_plots('val_acc')

# %% [markdown]
# ## Test Accuracy

# %%
draw_bar_plots('test_acc')

# %% [markdown]
# ### Final

# %%
draw_bar_plots('test_acc')

# %% [markdown]
# ## Train Accuracy

# %%
draw_bar_plots('train_accuracy')

# %% [markdown]
# ### Final

# %%
draw_bar_plots('train_accuracy')

# %% [markdown]
# ## Latency

# %%
draw_bar_plots('latency')

# %% [markdown]
# ## Total Time

# %%
draw_bar_plots('total_time')

# %% [markdown]
# ### Final

# %%
draw_bar_plots('total_time')

# %% [markdown]
# ## Time Cost
#
# "The time_cost is calculated as the total training time for a few (e.g., 12 epochs) plus the evaluation time for one epoch."
#  -- XAutoDL code

# %%
draw_bar_plots('time_cost')

# %% [markdown]
# ## Time Spent in Hours

# %%
draw_bar_plots('time_spent_in_hours')

# %% [markdown]
# ### Final

# %%
draw_bar_plots('time_spent_in_hours')
